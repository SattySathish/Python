# %%
import pandas as pd
import numpy as np
import torch

# %%
dataset = pd.read_csv("C:/Users/Admin/Desktop/Coding/Tensorflow/lifedata.csv")
dataset = dataset.drop(["Country","Year","GDP", "Population"], axis=1).dropna()

dataset = dataset.dropna(axis=0)
label = dataset["Life"]
feature = dataset.drop("Life",axis=1)

# features["Country"].unique()
feature = pd.get_dummies(feature)
# Out:
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0               263.0             62     0.01               71.279624
# 1               271.0             64     0.01               73.523582
# 2               268.0             66     0.01               73.219243
# 3               272.0             69     0.01               78.184215
# 4               275.0             71     0.01                7.097109
# ...               ...            ...      ...                     ...
# 2933            723.0             27     4.36                0.000000
# 2934            715.0             26     4.06                0.000000
# 2935             73.0             25     4.43                0.000000
# 2936            686.0             25     1.72                0.000000
# 2937            665.0             24     1.68                0.000000
#
#       Hepatitis B  Measles    BMI   under-five deaths   Polio  \
# 0            65.0      1154   19.1                  83    6.0
# 1            62.0       492   18.6                  86   58.0
# 2            64.0       430   18.1                  89   62.0
# 3            67.0      2787   17.6                  93   67.0
# 4            68.0      3013   17.2                  97   68.0
# ...           ...       ...    ...                 ...    ...
# 2933         68.0        31   27.1                  42   67.0
# 2934          7.0       998   26.7                  41    7.0
# 2935         73.0       304   26.3                  40   73.0
# 2936         76.0       529   25.9                  39   76.0
# 2937         79.0      1483   25.5                  39   78.0
#
#       Total expenditure  Diphtheria    HIV/AIDS   thinness  1-19 years  \
# 0                  8.16         65.0        0.1                   17.2
# 1                  8.18         62.0        0.1                   17.5
# 2                  8.13         64.0        0.1                   17.7
# 3                  8.52         67.0        0.1                   17.9
# 4                  7.87         68.0        0.1                   18.2
# ...                 ...          ...        ...                    ...
# 2933               7.13         65.0       33.6                    9.4
# 2934               6.52         68.0       36.7                    9.8
# 2935               6.53         71.0       39.8                    1.2
# 2936               6.16         75.0       42.1                    1.6
# 2937               7.10         78.0       43.5                   11.0
#
#        thinness 5-9 years  Income composition of resources  Schooling  \
# 0                    17.3                            0.479       10.1
# 1                    17.5                            0.476       10.0
# 2                    17.7                            0.470        9.9
# 3                    18.0                            0.463        9.8
# 4                    18.2                            0.454        9.5
# ...                   ...                              ...        ...
# 2933                  9.4                            0.407        9.2
# 2934                  9.9                            0.418        9.5
# 2935                  1.3                            0.427       10.0
# 2936                  1.7                            0.427        9.8
# 2937                 11.2                            0.434        9.8
#
#       Status_Developed  Status_Developing
# 0                    0                  1
# 1                    0                  1
# 2                    0                  1
# 3                    0                  1
# 4                    0                  1
# ...                ...                ...
# 2933                 0                  1
# 2934                 0                  1
# 2935                 0                  1
# 2936                 0                  1
# 2937                 0                  1
#
# [2083 rows x 18 columns]

# %%
features = np.array(feature)
labels = np.array(label).reshape(-1,1)
features = torch.tensor(features, dtype = torch.float32)
labels = torch.tensor(labels,dtype = torch.float32)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14584\1830388616.py:3: UserWarning: Failed to initialize NumPy: module compiled against API version 0x10 but this version of numpy is 0xf (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:68.)
#   features = torch.tensor(features, dtype = torch.float32)

# %%
model = torch.nn.Linear(18,1)
preds=model(features)

# %%
from torch.nn.functional import mse_loss

loss  = mse_loss(preds, labels)
print(loss)

loss.backward()

print(model.weight.grad)
print(model.bias.grad)
# Out:
# tensor(624816.0625, grad_fn=<MseLossBackward0>)
# tensor([[ 3.7213e+03,  8.5326e+04, -1.5542e+03, -1.3334e+06, -1.1322e+04,
#           1.2715e+07, -1.0328e+04,  1.1204e+05, -1.0886e+04, -9.9480e+02,
#          -1.0587e+04,  1.5962e+02,  1.3899e+03,  1.3856e+03, -1.1833e+02,
#          -2.2387e+03, -1.4470e+02,  5.8022e+01]])
# tensor([-86.6796])

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-10)

optimizer.step()
optimizer.zero_grad()

preds = model(features)
loss = mse_loss(preds, labels)
print(loss)
# Out:
# tensor(608605.2500, grad_fn=<MseLossBackward0>)

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-10)

epochs = 100000
for epoch in range(epochs):
    preds = model(features)
    loss = mse_loss(preds, labels)
    
    if (epoch+1)%1000 == 0:
        print(loss)

    loss.backward()
    
    optimizer.step()
    optimizer.zero_grad()
# Out:
# tensor(41740.8906, grad_fn=<MseLossBackward0>)
# tensor(12670.0225, grad_fn=<MseLossBackward0>)
# tensor(4815.4473, grad_fn=<MseLossBackward0>)
# tensor(2675.3103, grad_fn=<MseLossBackward0>)
# tensor(2074.6775, grad_fn=<MseLossBackward0>)
# tensor(1889.1570, grad_fn=<MseLossBackward0>)
# tensor(1815.9055, grad_fn=<MseLossBackward0>)
# tensor(1773.3524, grad_fn=<MseLossBackward0>)
# tensor(1739.5317, grad_fn=<MseLossBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Admin\Desktop\Coding\Tensorflow\life_regression.ipynb Cell 7 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Coding/Tensorflow/life_regression.ipynb#ch0000006?line=8'>9</a>     print(loss)
#      <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Coding/Tensorflow/life_regression.ipynb#ch0000006?line=10'>11</a> loss.backward()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Coding/Tensorflow/life_regression.ipynb#ch0000006?line=12'>13</a> optimizer.step()
#      <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Coding/Tensorflow/life_regression.ipynb#ch0000006?line=13'>14</a> optimizer.zero_grad()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\optimizer.py:109, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     107 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     108 with torch.autograd.profiler.record_function(profile_name):
# --> 109     return func(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\sgd.py:146, in SGD.step(self, closure)
#     143         else:
#     144             momentum_buffer_list.append(state['momentum_buffer'])
# --> 146 sgd(params_with_grad,
#     147     d_p_list,
#     148     momentum_buffer_list,
#     149     weight_decay=group['weight_decay'],
#     150     momentum=group['momentum'],
#     151     lr=group['lr'],
#     152     dampening=group['dampening'],
#     153     nesterov=group['nesterov'],
#     154     maximize=group['maximize'],
#     155     has_sparse_grad=has_sparse_grad,
#     156     foreach=group['foreach'])
#     158 # update momentum_buffers in state
#     159 for p, momentum_buffer in zip(params_with_grad, momentum_buffer_list):
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\sgd.py:197, in sgd(params, d_p_list, momentum_buffer_list, has_sparse_grad, foreach, weight_decay, momentum, lr, dampening, nesterov, maximize)
#     194 else:
#     195     func = _single_tensor_sgd
# --> 197 func(params,
#     198      d_p_list,
#     199      momentum_buffer_list,
#     200      weight_decay=weight_decay,
#     201      momentum=momentum,
#     202      lr=lr,
#     203      dampening=dampening,
#     204      nesterov=nesterov,
#     205      has_sparse_grad=has_sparse_grad,
#     206      maximize=maximize)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\sgd.py:241, in _single_tensor_sgd(params, d_p_list, momentum_buffer_list, weight_decay, momentum, lr, dampening, nesterov, maximize, has_sparse_grad)
#     238         d_p = buf
#     240 alpha = lr if maximize else -lr
# --> 241 param.add_(d_p, alpha=alpha)
#
# KeyboardInterrupt:
